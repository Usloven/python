# %% [markdown]
# <a href="https://colab.research.google.com/github/Usloven/python/blob/main/.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# ```
# #
# *Определить корни/
# *Найти интервалы, на которых функция возрастает
# *Найти интервалы, на которых функция убывает
# *Построить график
# *Вычислить вершину
# *Определить промежутки, на котором f > 0
# *Определить промежутки, на котором f < 0
# ```

# %% [markdown]
# Определить корни
# Найти интервалы, на которых функция возрастает
# Найти интервалы, на которых функция убывает
# Построить график
# Вычислить вершину
# Определить промежутки, на котором f > 0
# Определить промежутки, на котором f < 0

# %%
from sympy import *
x = Symbol('x', real=True)
expr =  - 18*x**3+5*x**2 + 10*x - 30 
expr1 = -12*x**4*sin(cos(x)) 
expr2 = -12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30

# %%
diff2= diff(expr1)
diff2
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x))

# %%
solve(expr,x, real=True) #корень
# Out:
# [5/54 - 565/(972*(-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3,
#  5/54 - (-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)),
#  -(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) + 5/54]

# %%
plot (expr, (x, -1000, 1000)) #графики функций на разных интервалах и графики разных частей функции
plot (expr1, (x, -2, 2))
plot (expr2, (x, -2, 2))
plot (expr1, -100, 100)
plot (expr2,  -100, 100)
